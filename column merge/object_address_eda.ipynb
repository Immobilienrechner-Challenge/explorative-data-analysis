# %% [markdown]
# Check the object datatype in DataFrame and extracting the important address coloumns and dropping
# unnecessary coloumns:
#
# unnecessary coloumns: ['Municipality', 'Municipality_merged', 'location_parsed', 'location']
#
# # Most important conclusion/do's
# extract from coloumn 'address' the street, zip_code, canton with the function extract_adress(df, col)
# for municipality use the coloumn 'Locality'

# %%
# Import Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import DataFarme
df = pd.read_csv("https://raw.githubusercontent.com/Immobilienrechner-Challenge/data/main/immoscout_cleaned_lat_lon_fixed_v9.csv")

# print head of DataFrame
df.head()

# Get information about DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13378 entries, 0 to 13377
# Columns: 108 entries, Unnamed: 0.1 to rooms
# dtypes: float64(53), int64(4), object(51)
# memory usage: 11.0+ MB
# /tmp/ipykernel_3724/213040399.py:2: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("https://raw.githubusercontent.com/Immobilienrechner-Challenge/data/main/immoscout_cleaned_lat_lon_fixed_v9.csv")

# %%
# Get from every column the data type
df.dtypes
# Out:
# Unnamed: 0             int64
# Unnamed: 0.1           int64
# Municipality          object
# Living space          object
# Plot area             object
#                       ...
# gde_workers_total    float64
# price_cleaned        float64
# type                  object
# Space extracted      float64
# rooms                float64
# Length: 108, dtype: object

# %%
# filter for columns with dtype object
df_objects = df[df.select_dtypes(include=['object']).columns]

# get len of columns with dtype object
len(df.select_dtypes(include=['object']).columns)
# Out:
# 51

# %%
# get every coloumn name with dtype object
df_objects.columns

# get every column name with dtype object and save it in a list
df_objects_list = df_objects.columns.tolist()

# display df_objects_list

print(df_objects_list)

# print len of df_objects_list
len(df_objects_list)

# create empty list for dropping the coloumn names in the future
drop_list = []
# Out:
# ['Municipality', 'Living space', 'Plot area', 'Floor space', 'Availability', 'location', 'description', 'detailed_description', 'url', 'table', 'Floor', 'detail_responsive#municipality', 'detail_responsive#surface_living', 'detail_responsive#floor', 'detail_responsive#available_from', 'Gemeinde', 'Wohnfläche', 'Stockwerk', 'Nutzfläche', 'Verfügbarkeit', 'Grundstücksfläche', 'detail_responsive#surface_property', 'detail_responsive#surface_usable', 'Commune', 'Surface habitable', 'Surface du terrain', 'Surface utile', 'Disponibilité', 'Étage', 'Comune', 'Superficie abitabile', 'Disponibilità', 'Gross return', 'Piano', 'Superficie del terreno', 'Superficie utile', 'Municipality_merged', 'Floor_merged', 'Living_space_merged', 'Floor_space_merged', 'Plot_area_merged', 'Availability_merged', 'location_parsed', 'title', 'details', 'address', 'price', 'link', 'details_structured', 'Locality', 'type']

# %%
# display DataFrame
df_objects.head(2)
# Out:
#   Municipality Living space Plot area Floor space Availability  \
# 0   Biberstein       100 m²       NaN         NaN   On request
# 1   Biberstein       156 m²    222 m²      242 m²   On request
#
#                                location  \
# 0                   5023 Biberstein, AG
# 1  Buhldenstrasse 8d5023 Biberstein, AG
#
#                                          description  \
# 0  3.5 rooms, 100 m²«Luxuriöse Attika-Wohnung mit...
# 1  4.5 rooms, 156 m²«Stilvolle Liegenschaft - ruh...
#
#                                 detailed_description  \
# 0  DescriptionLuxuriöse Attika-Wohnung direkt an ...
# 1  DescriptionStilvolle Liegenschaft an ruhiger L...
#
#                                                  url  \
# 0  https://www.immoscout24.ch//en/d/penthouse-buy...
# 1  https://www.immoscout24.ch//en/d/terrace-house...
#
#                                                table  ... Availability_merged  \
# ...

# %%
# check if there is a double entry in df_objects
print(df_objects.duplicated().sum())

# display the double entry
display(df_objects[df_objects.duplicated()])

# get the len of the double entry
len(df_objects[df_objects.duplicated()])

# get the index of the double entry
df_objects[df_objects.duplicated()].index

# drop the double entry
df_objects.drop_duplicates(inplace=True)

# get the shape from df_objects
df_objects.shape
# Out:
# 20
#        Municipality Living space Plot area Floor space Availability  \
# 23       Biberstein       100 m²       NaN         NaN   On request
# 24       Biberstein       156 m²    222 m²      242 m²   On request
# 25       Biberstein       154 m²    370 m²      257 m²   On request
# 26       Biberstein       124 m²    200 m²         NaN  Immediately
# 27       Buchs (AG)        95 m²       NaN         NaN  Immediately
# 28            Aarau        75 m²       NaN         NaN   On request
# 29       Buchs (AG)       190 m²    535 m²         NaN   On request
# 30            Aarau       127 m²       NaN         NaN   On request
# 32       Buchs (AG)        93 m²       NaN         NaN   On request
# 33            Aarau       258 m²   1005 m²         NaN   On request
# 34  Erlinsbach (AG)       190 m²   1063 m²      220 m²   On request
# 35            Aarau          NaN       NaN         NaN   On request
# 38  Erlinsbach (AG)       110 m²   2116 m²         NaN   On request
# ...

# %%
# selecting the columns Municipality and location, Municipality_merged, location_parsed, address, details_structured, Locality
df_address = df_objects[['Municipality', 'location', 'Municipality_merged', \
                         'location_parsed', 'address', 'Locality', 
                         'detail_responsive#municipality', 'Gemeinde']]

# %%
# display df_address
df_address
# Out:
#       Municipality                                    location  \
# 0       Biberstein                         5023 Biberstein, AG
# 1       Biberstein        Buhldenstrasse 8d5023 Biberstein, AG
# 2              NaN                            5022 Rombach, AG
# 3       Biberstein       Buhaldenstrasse 8A5023 Biberstein, AG
# 4         Küttigen                            5022 Rombach, AG
# ...            ...                                         ...
# 13373        Uster          Tägerackerstrasse 138610 Uster, ZH
# 13374   Volketswil                         8604 Volketswil, ZH
# 13375      Seuzach                            8472 Seuzach, ZH
# 13376    Zell (ZH)  Vordere Bähntalstrasse 18483 Kollbrunn, ZH
# 13377   Winterthur           Im Eichbühl 508405 Winterthur, ZH
#
#       Municipality_merged                                    location_parsed  \
# 0              Biberstein    Strasse:  plz:5023 Stadt: Biberstein Kanton: AG
# ...

# %%
street = df_address['location_parsed'].str.extract(r'^Strasse:(.+?) plz')


street.count()
# Out:
# 0    13341
# dtype: int64

# %%
# print the shape of df_address
print(df_address.shape)

# get the number of unique values in every column in df_address
print(df_address.nunique())

# get the sum of values in every column in df_address
df_address.count()
# Out:
# (13358, 8)
# Municipality                      1505
# location                          6330
# Municipality_merged               1512
# location_parsed                   6305
# address                           6330
# Locality                          1295
# detail_responsive#municipality     322
# Gemeinde                           123
# dtype: int64
# Municipality                      12426
# location                          13358
# Municipality_merged               12677
# location_parsed                   13341
# address                           13358
# Locality                          13358
# detail_responsive#municipality      451
# Gemeinde                            158
# dtype: int64

# %% [markdown]
# Municipality, Municipality_merged, location_parsed nach Na untersuchen

# %%
# get the sum of na values in Municipality, location, Municipality_merged, location_parsed, address, details_structured, Locality
print("Municipality sum of Na", df_address['Municipality'].isna().sum())
print("location sum of Na", df_address['location'].isna().sum())
print("Municipality_merged sum of Na", df_address['Municipality_merged'].isna().sum())
print("location_parsed sum of Na", df_address['location_parsed'].isna().sum())
print("address sum of Na", df_address['address'].isna().sum())
print("Locality sum of Na", df_address['Locality'].isna().sum())
print("detail_responsive#municipality sum of Na", df_address['detail_responsive#municipality'].isna().sum())
print("Gemeinde sum of Na", df_address['Gemeinde'].isna().sum())
# Out:
# Municipality sum of Na 932
# location sum of Na 0
# Municipality_merged sum of Na 681
# location_parsed sum of Na 17
# address sum of Na 0
# Locality sum of Na 0
# detail_responsive#municipality sum of Na 12907
# Gemeinde sum of Na 13200

# %%
# display df_adress
display(df_address.head(3))
# Out:
#   Municipality                              location Municipality_merged  \
# 0   Biberstein                   5023 Biberstein, AG          Biberstein
# 1   Biberstein  Buhldenstrasse 8d5023 Biberstein, AG          Biberstein
# 2          NaN                      5022 Rombach, AG                 NaN
#
#                                      location_parsed  \
# 0    Strasse:  plz:5023 Stadt: Biberstein Kanton: AG
# 1  Strasse:Buhldenstrasse  8d plz:5023 Stadt: Bib...
# 2       Strasse:  plz:5022 Stadt: Rombach Kanton: AG
#
#                                   address    Locality
# 0                     5023 Biberstein, AG  Biberstein
# 1  Buhldenstrasse 8d, 5023 Biberstein, AG  Biberstein
# 2                        5022 Rombach, AG       Aarau

# %%
# drop Municipality, municipality_merged and location_parsed
df_address.drop(['Municipality', 'Municipality_merged', \
                'location_parsed', 'detail_responsive#municipality', \
                'Gemeinde'], axis=1, inplace=True)

# add drop coloumns to drop_list
drop_list.append('Municipality')
drop_list.append('Municipality_merged')
drop_list.append('location_parsed')
drop_list.append('detail_responsive#municipality')
drop_list.append('Gemeinde')

# display df_address
df_address
# Out:
# C:\Users\Si Ben Tran\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                          location  \
# 0                             5023 Biberstein, AG
# 1            Buhldenstrasse 8d5023 Biberstein, AG
# 2                                5022 Rombach, AG
# 3           Buhaldenstrasse 8A5023 Biberstein, AG
# 4                                5022 Rombach, AG
# ...                                           ...
# 13373          Tägerackerstrasse 138610 Uster, ZH
# 13374                         8604 Volketswil, ZH
# 13375                            8472 Seuzach, ZH
# 13376  Vordere Bähntalstrasse 18483 Kollbrunn, ZH
# 13377           Im Eichbühl 508405 Winterthur, ZH
#
# ...

# %%
# count number of values in df_address
df_address.count()
# Out:
# location    13358
# address     13358
# Locality    13358
# dtype: int64

# %%
# Drop coloumn location
df_address.drop(['location'], axis=1, inplace=True)

# add to drop_list
drop_list.append('location')
# Out:
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\202959183.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_address.drop(['location'], axis=1, inplace=True)

# %%
# display df_address
df_address.head(3)
# Out:
#                                   address    Locality
# 0                     5023 Biberstein, AG  Biberstein
# 1  Buhldenstrasse 8d, 5023 Biberstein, AG  Biberstein
# 2                        5022 Rombach, AG       Aarau

# %%
# extract the street from address coloumn until the start of the first comma
df_address["street"] = df_address['address'].str.extract(r'(.+?),')

# replace the whole value in street if it starts with a number
df_address['street'] = df_address['street'].str.replace(r'^\d+\s\w+', 'NaN')

# display df_address
df_address.head(3)
# Out:
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\3114208687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_address["street"] = df_address['address'].str.extract(r'(.+?),')
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\3114208687.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_address['street'] = df_address['street'].str.replace(r'^\d+\s\w+', 'NaN')
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\3114208687.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# extract the zip code from the coloumn address and remove zip code from address
df_address['zip_code'] = df_address['address'].str.extract(r'(\d{4})')

# check na values in zip_code
print(df_address['zip_code'].isna().sum())

# display df_address
df_address.head(3)
# Out:
# 0
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\562481002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_address['zip_code'] = df_address['address'].str.extract(r'(\d{4})')
#                                   address    Locality             street  \
# 0                     5023 Biberstein, AG  Biberstein                NaN
# 1  Buhldenstrasse 8d, 5023 Biberstein, AG  Biberstein  Buhldenstrasse 8d
# 2                        5022 Rombach, AG       Aarau                NaN
#
#   zip_code
# 0     5023
# 1     5023
# 2     5022

# %%
# extract canton from address
df_address['canton'] = df_address['address'].str.extract(r'(\w{2})$')

# check na values in canton
print(df_address['canton'].isna().sum())

# display df_address
df_address.head(3)
# Out:
# 0
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\495682280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_address['canton'] = df_address['address'].str.extract(r'(\w{2})$')
#                                   address    Locality             street  \
# 0                     5023 Biberstein, AG  Biberstein                NaN
# 1  Buhldenstrasse 8d, 5023 Biberstein, AG  Biberstein  Buhldenstrasse 8d
# 2                        5022 Rombach, AG       Aarau                NaN
#
#   zip_code canton
# 0     5023     AG
# 1     5023     AG
# 2     5022     AG

# %%
# drop the address coloumn
df_address.drop(['address'], axis=1, inplace=True)

# display df_address
df_address.head(3)
# Out:
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\3281279493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_address.drop(['address'], axis=1, inplace=True)
#      Locality             street zip_code canton
# 0  Biberstein                NaN     5023     AG
# 1  Biberstein  Buhldenstrasse 8d     5023     AG
# 2       Aarau                NaN     5022     AG

# %%
# create an function that extract address
def extract_address(df, col):
    '''
    function to extract the coloumn address into
    street, zip_code and canton

    df: DataFrame 
    col: coloumn name (address)
    '''

    # extract the street from address coloumn until the start of the first comma
    df['street'] = df[col].str.extract(r'(.+?),')
    
    # replace the whole value in street if it starts with a number
    df['street'] = df[col].str.replace(r'^\d+\s\w+', 'NaN')

    # extract the zip code from the coloumn address and remove zip code from address
    df['zip_code'] = df[col].str.extract(r'(\d{4})')

    # extract canton from address
    df['canton'] = df[col].str.extract(r'(\w{2})$')
    
    # drop the address coloumn
    df.drop([col], axis=1, inplace=True)

    return df

# %%
# testing the function with df_objects
df_objects = extract_address(df_objects, 'address')

# display df_objects
df_objects.head(3)
# Out:
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\2462876148.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['street'] = df[col].str.extract(r'(.+?),')
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\2462876148.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['street'] = df[col].str.replace(r'^\d+\s\w+', 'NaN')
# C:\Users\Si Ben Tran\AppData\Local\Temp\ipykernel_17264\2462876148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# coloumns to drop 
drop_list
# Out:
# ['Municipality', 'Municipality_merged', 'location_parsed', 'location']
