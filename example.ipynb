# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Immobilienrechner-Challenge/data/main/immoscout_cleaned_lat_lon_fixed_v7.csv")
data
# Out:
# /Users/gabriel.torres/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0 Municipality Living space Plot area Floor space  \
# 0               0   Biberstein       100 m²       NaN         NaN
# 1               1   Biberstein       156 m²    222 m²      242 m²
# 2               2          NaN          NaN       NaN         NaN
# 3               3   Biberstein       154 m²    370 m²      257 m²
# 4               4     Küttigen       142 m²       NaN         NaN
# ...           ...          ...          ...       ...         ...
# 13373       13373        Uster        70 m²       NaN         NaN
# 13374       13374   Volketswil          NaN    284 m²         NaN
# 13375       13375      Seuzach       150 m²    160 m²         NaN
# ...
